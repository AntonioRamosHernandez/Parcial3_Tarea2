# %%
##Ramos Hernández Antonio

import matplotlib.pyplot as plt


def x(y):
    return  0.25 + (0.25*y)
def y(x,z):
    return  0.25 +(0.25*x) + (0.25*z)
def z(y,w):
    return  0.25 + (0.25*y) + (0.25*w)
def w(z):
    return  0.25 + (0.25*z)


def g_next():
    
    
    x1 = [0.0]
    x2 = [0.0]
    x3 = [0.0]
    x4 = [0.0]
    i=0
     
    while (i<10):
        
            x1.append(x(x2[i]))
            x2.append(y(x1[i+1],x3[i]))
            x3.append(z(x2[i+1],x4[i]))
            x4.append(w(x3[i+1]))
            i+=1
            
            
    
    print('x: '+ str(x1)+'\n' )
    print('y: '+ str(x2)+'\n' )
    print('z: '+ str(x3)+'\n' )
    print('w: '+ str(x4)+'\n' )
    
    plt.plot(x1,label="x",color='b')
    plt.plot(x2,label="y",color='r')
    plt.plot(x3,label="z",color='y')
    plt.plot(x4,label="w",color='g')
    
    plt.title("Gauss Seidel ", fontsize = 24)
    
    plt.legend()
    plt.show()

    

g_next()
# Out:
# x: [0.0, 0.25, 0.328125, 0.353515625, 0.36187744140625, 0.3633460998535156, 0.363588809967041, 0.3636285811662674, 0.3636350901797414, 0.3636361552635208, 0.36363632954089553]
#
# y: [0.0, 0.3125, 0.4140625, 0.447509765625, 0.4533843994140625, 0.45435523986816406, 0.4545143246650696, 0.45454036071896553, 0.4545446210540831, 0.4545453181635821, 0.45454543222967914]
#
# z: [0.0, 0.328125, 0.4365234375, 0.45166015625, 0.4540748596191406, 0.4544684886932373, 0.4545328617095947, 0.45454339403659105, 0.4545451173908077, 0.454545399377821, 0.4545454455185336]
#
# w: [0.0, 0.33203125, 0.359130859375, 0.3629150390625, 0.36351871490478516, 0.3636171221733093, 0.3636332154273987, 0.36363584850914776, 0.36363627934770193, 0.36363634984445525, 0.3636363613796334]
